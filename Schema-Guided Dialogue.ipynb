# %% [markdown]
# # SGD(Schema-Guided Dialogue) Dataset
#
# - Paper: [Towards Scalable Multi-domain Conversational Agents: The Schema-Guided Dialogue Dataset](https://arxiv.org/abs/1909.05855) (AAAI 2020)
# - Brief Explanation: https://paperswithcode.com/dataset/sgd
# - Official Repository: https://github.com/google-research-datasets/dstc8-schema-guided-dialogue
#
# The Schema-Guided Dialogue (SGD) dataset consists of over **20k annotated multi-domain, task-oriented conversations** between a human and a virtual assistant. These conversations involve interactions with services and APIs spanning **20 domains, ranging from banks and events to media, calendar, travel, and weather**. For most of these domains, the dataset contains multiple different APIs, many of which have overlapping functionalities but different interfaces, which reflects common real-world scenarios. The wide range of available annotations can be used for intent prediction, slot filling, dialogue state tracking, policy imitation learning, language generation, user simulation learning, among other tasks in large-scale virtual assistants. Besides these, the dataset has **unseen domains and services in the evaluation set** to quantify the performance in **zero-shot or few shot** settings.

# %%
# %load_ext lab_black

# %%
import os
import json
import glob
from pprint import pprint

# %%
trn_pth = "./train"
dev_pth = "./dev"
tst_pth = "./test"

# %%
trn_dialogues = []
for dialog in glob.glob(os.path.join(trn_pth, "dialogues_*.json")):
    with open(dialog) as f:
        json_object = json.load(f)
    trn_dialogues.append(json_object)

# %%
# Number of total json file (train)
len(trn_dialogues)
# Out:
# 127

# %%
# Number of dialogues in each json file (train)
pprint(" ".join([str(len(dlog)) for dlog in trn_dialogues]))
# Out:
# ('128 128 128 128 128 128 128 128 128 128 128 128 128 128 128 128 128 128 128 '
#  '128 128 128 128 128 128 128 128 128 128 128 128 128 128 128 128 128 128 128 '
#  '128 128 128 128 128 128 128 128 127 126 128 128 128 115 128 128 128 128 128 '
#  '128 128 128 128 128 128 128 62 128 128 128 126 128 128 128 128 128 128 128 '
#  '128 128 127 128 128 128 128 128 128 128 128 128 103 128 128 128 128 128 128 '
#  '128 128 128 128 128 128 128 128 128 128 128 128 128 128 128 128 128 128 128 '
#  '128 128 128 128 128 128 128 127 128 125 128 128 128')

# %%
# Total number of dialogues
def count_data(root):
    total = 0
    for dlog in glob.glob(os.path.join(root, "dialogues_*.json")):
        with open(dlog) as f:
            json_object = json.load(f)
        total += len(json_object)
    return total


pprint(f"Total number of dialogues in trn data is {count_data(trn_pth)}")
pprint(f"Total number of dialogues in dev data is {count_data(dev_pth)}")
pprint(f"Total number of dialogues in tst data is {count_data(tst_pth)}")
# Out:
# 'Total number of dialogues in trn data is 16142'
# 'Total number of dialogues in dev data is 2482'
# 'Total number of dialogues in tst data is 4201'

# %% [markdown]
# ### Structure
# ```sh
# dstc8-schema-guided-dialogue/
#         └─ train/
#             └─ dialogues_001.json
#                     ├─ dialog_0 (key: dialogue_id, services, turns)
#                     ├─ ...
#                     └─ dialog_k (key: dialogue_id, services, turns)
#             ├─ ...
#             ├─ dialogues_127.json
#             └─ schema.json
#         ├─ dev/
#         └─ test/
# ```

# %%
sample = trn_dialogues[10][0]

# hierarchical dictionary keys
pprint(sample.keys())
pprint(sample["turns"][0].keys())
pprint(sample["turns"][0]["frames"][0].keys())
pprint(sample["turns"][0]["frames"][0]["actions"][0].keys())
# Out:
# dict_keys(['dialogue_id', 'services', 'turns'])
# dict_keys(['frames', 'speaker', 'utterance'])
# dict_keys(['actions', 'service', 'slots', 'state'])
# dict_keys(['act', 'canonical_values', 'slot', 'values'])

# %%
pprint(sample)
# Out:
# {'dialogue_id': '13_00000',
#  'services': ['Movies_1'],
#  'turns': [{'frames': [{'actions': [{'act': 'INFORM_INTENT',
#                                      'canonical_values': ['FindMovies'],
#                                      'slot': 'intent',
#                                      'values': ['FindMovies']}],
#                         'service': 'Movies_1',
#                         'slots': [],
#                         'state': {'active_intent': 'FindMovies',
#                                   'requested_slots': [],
#                                   'slot_values': {}}}],
#             'speaker': 'USER',
#             'utterance': 'A movie will help me overcome the monotonous of the '
#                          'day. Is there any good movie?'},
#            {'frames': [{'actions': [{'act': 'REQUEST',
#                                      'canonical_values': [],
#                                      'slot': 'location',
#                                      'values': []}],
#                         'service': 'Movies_1',
#                         'slots': []}],
#             'speaker': 'SYSTEM',
#             'utterance': 'Where do you want to see?'},
#            {'frames': [{'actions': [{'act': 'INFORM',
#                                      'canonical_values': ['San Francisco'],
#                                      'slot': 'location',
#                                      'values': ['SFO']}],
#                         'service': 'Movies_1',
#                         'slots': [{'exclusive_end': 22,
#                                    'slot': 'location',
#                                    'start': 19}],
#                         'state': {'active_intent': 'FindMovies',
#                                   'requested_slots': [],
#                                   'slot_values': {'location': ['SFO']}}}],
#             'speaker': 'USER',
#             'utterance': 'It will be fine in SFO'},
#            {'frames': [{'actions': [{'act': 'OFFER',
#                                      'canonical_values': ['Ash Is Purest White',
#                                                           'Body Double',
#                                                           'Captain Marvel'],
#                                      'slot': 'movie_name',
#                                      'values': ['Ash Is Purest White',
#                                                 'Body Double',
#                                                 'Captain Marvel']}],
#                         'service': 'Movies_1',
#                         'service_call': {'method': 'FindMovies',
#                                          'parameters': {'location': 'San '
#                                                                     'Francisco'}},
#                         'service_results': [{'genre': 'Crime',
#                                              'location': 'San Francisco',
#                                              'movie_name': 'Ash Is Purest '
#                                                            'White',
#                                              'price': '14',
#                                              'show_type': 'imax',
#                                              'street_address': '1 Embarcadero '
#                                                                'Center',
#                                              'theater_name': "Landmark's "
#                                                              'Embarcadero '
#                                                              'Center Cinema'},
#                                             {'genre': 'Mystery',
#                                              'location': 'San Francisco',
#                                              'movie_name': 'Body Double',
#                                              'price': '14',
#                                              'show_type': 'regular',
#                                              'street_address': '2550 Mission '
#                                                                'Street',
#                                              'theater_name': 'Alamo Drafthouse '
#                                                              'Cinema'},
#                                             {'genre': 'Adventure',
#                                              'location': 'San Francisco',
#                                              'movie_name': 'Captain Marvel',
#                                              'price': '21',
#                                              'show_type': 'regular',
#                                              'street_address': '835 Market '
#                                                                'Street',
#                                              'theater_name': 'Century San '
#                                                              'Francisco Centre '
#                                                              '9 & XD'},
#                                             {'genre': 'Mystery',
#                                              'location': 'San Francisco',
#                                              'movie_name': 'Citizen Kane',
#                                              'price': '20',
#                                              'show_type': '3d',
#                                              'street_address': '3290 '
#                                                                'Sacramento '
#                                                                'Street',
#                                              'theater_name': 'Vogue Theatre'},
#                                             {'genre': 'Drama',
#                                              'location': 'San Francisco',
#                                              'movie_name': 'Dogman',
#                                              'price': '18',
#                                              'show_type': '3d',
#                                              'street_address': '601 Van Ness '
#                                                                'Avenue',
#                                              'theater_name': "Landmark's Opera "
#                                                              'Plaza Cinema'},
#                                             {'genre': 'Fantasy',
#                                              'location': 'San Francisco',
#                                              'movie_name': 'Dumbo',
#                                              'price': '15',
#                                              'show_type': 'imax',
#                                              'street_address': '135 4th Street '
#                                                                'Suite 3000',
#                                              'theater_name': 'AMC Metreon 16'},
#                                             {'genre': 'Comedy',
#                                              'location': 'San Francisco',
#                                              'movie_name': 'Family',
#                                              'price': '12',
#                                              'show_type': 'regular',
#                                              'street_address': '501 Buckingham '
#                                                                'Way',
#                                              'theater_name': 'United Artists '
#                                                              'Stonestown Twin'},
#                                             {'genre': 'Comedy',
#                                              'location': 'San Francisco',
#                                              'movie_name': 'Gloria Bell',
#                                              'price': '16',
#                                              'show_type': 'imax',
#                                              'street_address': '601 Van Ness '
#                                                                'Avenue',
#                                              'theater_name': "Landmark's Opera "
#                                                              'Plaza Cinema'},
#                                             {'genre': 'Fantasy',
#                                              'location': 'San Francisco',
#                                              'movie_name': 'Hellboy',
#                                              'price': '22',
#                                              'show_type': 'imax',
#                                              'street_address': '835 Market '
#                                                                'Street',
#                                              'theater_name': 'Century San '
#                                                              'Francisco Centre '
#                                                              '9 & XD'},
#                                             {'genre': 'Thriller',
#                                              'location': 'San Francisco',
#                                              'movie_name': 'Hotel Mumbai',
#                                              'price': '10',
#                                              'show_type': 'imax',
#                                              'street_address': '2340 Chestnut '
#                                                                'Street',
#                                              'theater_name': 'Presidio '
#                                                              'Theatre'}],
#                         'slots': [{'exclusive_end': 28,
#                                    'slot': 'movie_name',
#                                    'start': 9},
#                                   {'exclusive_end': 41,
#                                    'slot': 'movie_name',
#                                    'start': 30},
#                                   {'exclusive_end': 60,
#                                    'slot': 'movie_name',
#                                    'start': 46}]}],
#             'speaker': 'SYSTEM',
#             'utterance': 'There is Ash Is Purest White, Body Double and '
#                          'Captain Marvel, which one do you prefer?'},
#            {'frames': [{'actions': [{'act': 'REQUEST_ALTS',
#                                      'canonical_values': [],
#                                      'slot': '',
#                                      'values': []}],
#                         'service': 'Movies_1',
#                         'slots': [],
#                         'state': {'active_intent': 'FindMovies',
#                                   'requested_slots': [],
#                                   'slot_values': {'location': ['SFO']}}}],
#             'speaker': 'USER',
#             'utterance': 'Look for any other movies'},
#            {'frames': [{'actions': [{'act': 'OFFER',
#                                      'canonical_values': ['Citizen Kane',
#                                                           'Dogman',
#                                                           'Dumbo'],
#                                      'slot': 'movie_name',
#                                      'values': ['Citizen Kane',
#                                                 'Dogman',
#                                                 'Dumbo']}],
#                         'service': 'Movies_1',
#                         'slots': [{'exclusive_end': 24,
#                                    'slot': 'movie_name',
#                                    'start': 12},
#                                   {'exclusive_end': 32,
#                                    'slot': 'movie_name',
#                                    'start': 26},
#                                   {'exclusive_end': 42,
#                                    'slot': 'movie_name',
#                                    'start': 37}]}],
#             'speaker': 'SYSTEM',
#             'utterance': 'Do you like Citizen Kane, Dogman, or Dumbo?'},
#            {'frames': [{'actions': [{'act': 'INFORM',
#                                      'canonical_values': ['Vallejo'],
#                                      'slot': 'location',
#                                      'values': ['Vallejo']},
#                                     {'act': 'INFORM',
#                                      'canonical_values': ['imax'],
#                                      'slot': 'show_type',
#                                      'values': ['imax']},
#                                     {'act': 'REQUEST_ALTS',
#                                      'canonical_values': [],
#                                      'slot': '',
#                                      'values': []}],
#                         'service': 'Movies_1',
#                         'slots': [{'exclusive_end': 38,
#                                    'slot': 'location',
#                                    'start': 31}],
#                         'state': {'active_intent': 'FindMovies',
#                                   'requested_slots': [],
#                                   'slot_values': {'location': ['Vallejo'],
#                                                   'show_type': ['imax']}}}],
#             'speaker': 'USER',
#             'utterance': 'Try some other particularly in Vallejo, imax show.'},
#            {'frames': [{'actions': [{'act': 'OFFER',
#                                      'canonical_values': ['Hellboy'],
#                                      'slot': 'movie_name',
#                                      'values': ['Hellboy']}],
#                         'service': 'Movies_1',
#                         'service_call': {'method': 'FindMovies',
#                                          'parameters': {'location': 'Vallejo',
#                                                         'show_type': 'imax'}},
#                         'service_results': [{'genre': 'Fantasy',
#                                              'location': 'Vallejo',
#                                              'movie_name': 'Dumbo',
#                                              'price': '19',
#                                              'show_type': 'imax',
#                                              'street_address': '109 Plaza Dr. '
#                                                                'Gateway Plaza '
#                                                                'Center',
#                                              'theater_name': 'Century Vallejo '
#                                                              '14'},
#                                             {'genre': 'Fantasy',
#                                              'location': 'Vallejo',
#                                              'movie_name': 'Hellboy',
#                                              'price': '25',
#                                              'show_type': 'imax',
#                                              'street_address': '109 Plaza Dr. '
#                                                                'Gateway Plaza '
#                                                                'Center',
#                                              'theater_name': 'Century Vallejo '
#                                                              '14'}],
#                         'slots': [{'exclusive_end': 12,
#                                    'slot': 'movie_name',
#                                    'start': 5}]}],
#             'speaker': 'SYSTEM',
#             'utterance': 'Will Hellboy please you?'},
#            {'frames': [{'actions': [{'act': 'INFORM_INTENT',
#                                      'canonical_values': ['GetTimesForMovie'],
#                                      'slot': 'intent',
#                                      'values': ['GetTimesForMovie']},
#                                     {'act': 'SELECT',
#                                      'canonical_values': ['Hellboy'],
#                                      'slot': 'movie_name',
#                                      'values': ['Hellboy']}],
#                         'service': 'Movies_1',
#                         'slots': [{'exclusive_end': 20,
#                                    'slot': 'movie_name',
#                                    'start': 13}],
#                         'state': {'active_intent': 'GetTimesForMovie',
#                                   'requested_slots': [],
#                                   'slot_values': {'location': ['Vallejo'],
#                                                   'movie_name': ['Hellboy'],
#                                                   'show_type': ['imax']}}}],
#             'speaker': 'USER',
#             'utterance': 'Thats great, Hellboy will do. Show time please'},
#            {'frames': [{'actions': [{'act': 'REQUEST',
#                                      'canonical_values': [],
#                                      'slot': 'show_date',
#                                      'values': []}],
#                         'service': 'Movies_1',
#                         'slots': []}],
#             'speaker': 'SYSTEM',
#             'utterance': 'Which date do you prefer?'},
#            {'frames': [{'actions': [{'act': 'INFORM',
#                                      'canonical_values': ['2019-03-02'],
#                                      'slot': 'show_date',
#                                      'values': ['2nd of March']}],
#                         'service': 'Movies_1',
#                         'slots': [{'exclusive_end': 15,
#                                    'slot': 'show_date',
#                                    'start': 3}],
#                         'state': {'active_intent': 'GetTimesForMovie',
#                                   'requested_slots': [],
#                                   'slot_values': {'location': ['Vallejo'],
#                                                   'movie_name': ['Hellboy'],
#                                                   'show_date': ['2nd of March'],
#                                                   'show_type': ['imax']}}}],
#             'speaker': 'USER',
#             'utterance': 'On 2nd of March.'},
#            {'frames': [{'actions': [{'act': 'OFFER',
#                                      'canonical_values': ['13:30'],
#                                      'slot': 'show_time',
#                                      'values': ['1:30 pm']},
#                                     {'act': 'OFFER',
#                                      'canonical_values': ['Century Vallejo 14'],
#                                      'slot': 'theater_name',
#                                      'values': ['Century Vallejo 14']}],
#                         'service': 'Movies_1',
#                         'service_call': {'method': 'GetTimesForMovie',
#                                          'parameters': {'location': 'Vallejo',
#                                                         'movie_name': 'Hellboy',
#                                                         'show_date': '2019-03-02',
#                                                         'show_type': 'imax'}},
#                         'service_results': [{'genre': 'Fantasy',
#                                              'location': 'Vallejo',
#                                              'movie_name': 'Hellboy',
#                                              'price': '25',
#                                              'show_date': '2019-03-02',
#                                              'show_time': '13:30',
#                                              'show_type': 'imax',
#                                              'street_address': '109 Plaza Dr. '
#                                                                'Gateway Plaza '
#                                                                'Center',
#                                              'theater_name': 'Century Vallejo '
#                                                              '14'}],
#                         'slots': [{'exclusive_end': 38,
#                                    'slot': 'show_time',
#                                    'start': 31},
#                                   {'exclusive_end': 60,
#                                    'slot': 'theater_name',
#                                    'start': 42}]}],
#             'speaker': 'SYSTEM',
#             'utterance': 'Okm then you can enjoy show at 1:30 pm in Century '
#                          'Vallejo 14.'},
#            {'frames': [{'actions': [{'act': 'REQUEST',
#                                      'canonical_values': [],
#                                      'slot': 'genre',
#                                      'values': []},
#                                     {'act': 'REQUEST',
#                                      'canonical_values': [],
#                                      'slot': 'price',
#                                      'values': []}],
#                         'service': 'Movies_1',
#                         'slots': [],
#                         'state': {'active_intent': 'GetTimesForMovie',
#                                   'requested_slots': ['genre', 'price'],
#                                   'slot_values': {'location': ['Vallejo'],
#                                                   'movie_name': ['Hellboy'],
#                                                   'show_date': ['2nd of March'],
#                                                   'show_type': ['imax']}}}],
#             'speaker': 'USER',
#             'utterance': 'Do you know the genre of movie and fare of ticket.'},
#            {'frames': [{'actions': [{'act': 'INFORM',
#                                      'canonical_values': ['Fantasy'],
#                                      'slot': 'genre',
#                                      'values': ['Fantasy']},
#                                     {'act': 'INFORM',
#                                      'canonical_values': ['25'],
#                                      'slot': 'price',
#                                      'values': ['$25']}],
#                         'service': 'Movies_1',
#                         'slots': [{'exclusive_end': 7,
#                                    'slot': 'genre',
#                                    'start': 0},
#                                   {'exclusive_end': 32,
#                                    'slot': 'price',
#                                    'start': 29}]}],
#             'speaker': 'SYSTEM',
#             'utterance': 'Fantasy category and cost is $25.'},
#            {'frames': [{'actions': [{'act': 'REQUEST_ALTS',
#                                      'canonical_values': [],
#                                      'slot': '',
#                                      'values': []}],
#                         'service': 'Movies_1',
#                         'slots': [],
#                         'state': {'active_intent': 'GetTimesForMovie',
#                                   'requested_slots': [],
#                                   'slot_values': {'location': ['Vallejo'],
#                                                   'movie_name': ['Hellboy'],
#                                                   'show_date': ['2nd of March'],
#                                                   'show_type': ['imax']}}}],
#             'speaker': 'USER',
#             'utterance': 'Is there any other show time for that.'},
#            {'frames': [{'actions': [{'act': 'NOTIFY_FAILURE',
#                                      'canonical_values': [],
#                                      'slot': '',
#                                      'values': []},
#                                     {'act': 'REQ_MORE',
#                                      'canonical_values': [],
#                                      'slot': '',
#                                      'values': []}],
#                         'service': 'Movies_1',
#                         'service_call': {'method': 'GetTimesForMovie',
#                                          'parameters': {'location': 'Vallejo',
#                                                         'movie_name': 'Hellboy',
#                                                         'show_date': '2019-03-02',
#                                                         'show_type': 'imax'}},
#                         'service_results': [],
#                         'slots': []}],
#             'speaker': 'SYSTEM',
#             'utterance': 'No other show time. any other help you need?'},
#            {'frames': [{'actions': [{'act': 'INFORM',
#                                      'canonical_values': ['2019-03-01'],
#                                      'slot': 'show_date',
#                                      'values': ['March 1st']},
#                                     {'act': 'INFORM',
#                                      'canonical_values': ['Century Vallejo 14'],
#                                      'slot': 'theater_name',
#                                      'values': ['Century Vallejo']},
#                                     {'act': 'INFORM_INTENT',
#                                      'canonical_values': ['GetTimesForMovie'],
#                                      'slot': 'intent',
#                                      'values': ['GetTimesForMovie']}],
#                         'service': 'Movies_1',
#                         'slots': [{'exclusive_end': 42,
#                                    'slot': 'show_date',
#                                    'start': 33},
#                                   {'exclusive_end': 65,
#                                    'slot': 'theater_name',
#                                    'start': 50}],
#                         'state': {'active_intent': 'GetTimesForMovie',
#                                   'requested_slots': [],
#                                   'slot_values': {'location': ['Vallejo'],
#                                                   'movie_name': ['Hellboy'],
#                                                   'show_date': ['March 1st'],
#                                                   'show_type': ['imax'],
#                                                   'theater_name': ['Century '
#                                                                    'Vallejo',
#                                                                    'Century '
#                                                                    'Vallejo '
#                                                                    '14']}}}],
#             'speaker': 'USER',
#             'utterance': 'Yeah, I have changed the date to March 1st and at '
#                          'Century Vallejo.'},
#            {'frames': [{'actions': [{'act': 'OFFER',
#                                      'canonical_values': ['22:30'],
#                                      'slot': 'show_time',
#                                      'values': ['10:30 pm']},
#                                     {'act': 'OFFER',
#                                      'canonical_values': ['Century Vallejo 14'],
#                                      'slot': 'theater_name',
#                                      'values': ['Century Vallejo 14']},
#                                     {'act': 'INFORM_COUNT',
#                                      'canonical_values': ['1'],
#                                      'slot': 'count',
#                                      'values': ['1']}],
#                         'service': 'Movies_1',
#                         'service_call': {'method': 'GetTimesForMovie',
#                                          'parameters': {'location': 'Vallejo',
#                                                         'movie_name': 'Hellboy',
#                                                         'show_date': '2019-03-01',
#                                                         'show_type': 'imax',
#                                                         'theater_name': 'Century '
#                                                                         'Vallejo '
#                                                                         '14'}},
#                         'service_results': [{'genre': 'Fantasy',
#                                              'location': 'Vallejo',
#                                              'movie_name': 'Hellboy',
#                                              'price': '25',
#                                              'show_date': '2019-03-01',
#                                              'show_time': '22:30',
#                                              'show_type': 'imax',
#                                              'street_address': '109 Plaza Dr. '
#                                                                'Gateway Plaza '
#                                                                'Center',
#                                              'theater_name': 'Century Vallejo '
#                                                              '14'}],
#                         'slots': [{'exclusive_end': 31,
#                                    'slot': 'show_time',
#                                    'start': 23},
#                                   {'exclusive_end': 53,
#                                    'slot': 'theater_name',
#                                    'start': 35}]}],
#             'speaker': 'SYSTEM',
#             'utterance': 'There is 1 showtime at 10:30 pm in Century Vallejo '
#                          '14.'},
#            {'frames': [{'actions': [{'act': 'SELECT',
#                                      'canonical_values': [],
#                                      'slot': '',
#                                      'values': []},
#                                     {'act': 'GOODBYE',
#                                      'canonical_values': [],
#                                      'slot': '',
#                                      'values': []}],
#                         'service': 'Movies_1',
#                         'slots': [],
#                         'state': {'active_intent': 'GetTimesForMovie',
#                                   'requested_slots': [],
#                                   'slot_values': {'location': ['Vallejo'],
#                                                   'movie_name': ['Hellboy'],
#                                                   'show_date': ['March 1st'],
#                                                   'show_time': ['10:30 pm'],
#                                                   'show_type': ['imax'],
#                                                   'theater_name': ['Century '
#                                                                    'Vallejo',
#                                                                    'Century '
#                                                                    'Vallejo '
#                                                                    '14']}}}],
#             'speaker': 'USER',
#             'utterance': 'Great, that will be fine.'},
#            {'frames': [{'actions': [{'act': 'GOODBYE',
#                                      'canonical_values': [],
#                                      'slot': '',
#                                      'values': []}],
#                         'service': 'Movies_1',
#                         'slots': []}],
#             'speaker': 'SYSTEM',
#             'utterance': 'Have a great day.'}]}
